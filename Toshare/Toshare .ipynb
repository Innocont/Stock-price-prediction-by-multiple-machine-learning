# %%
import tushare as ts
ts.set_token('your token')
pro = ts.pro_api()
df = ts.pro_bar(ts_code='600519.SH', adj='qfq', start_date='20000101', end_date='20211231')
df.to_csv("train_data.csv")

# %%
df.head()
# Out:
#      ts_code trade_date  open  high   low  close  pre_close  change  pct_chg  \
# 0  601939.SH   20211231  5.86  5.87  5.84   5.86       5.87   -0.01  -0.1704
# 1  601939.SH   20211230  5.87  5.88  5.85   5.87       5.87    0.00   0.0000
# 2  601939.SH   20211229  5.89  5.91  5.86   5.87       5.91   -0.04  -0.6768
# 3  601939.SH   20211228  5.88  5.92  5.87   5.91       5.87    0.04   0.6814
# 4  601939.SH   20211227  5.89  5.90  5.87   5.87       5.91   -0.04  -0.6768
#
#          vol      amount
# 0  490953.91  287442.721
# 1  471583.95  276509.056
# 2  476374.64  280098.450
# 3  593569.65  350286.115
# 4  478058.91  281176.898
